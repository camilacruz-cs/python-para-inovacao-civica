# %% [markdown]
# <a href="https://colab.research.google.com/github/camilacruz-cs/python-para-inovacao-civica/blob/main/seman_1_estrutura_de_controle_e_repeticao_python_inovacao_civica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Escola de Dados - Python para inovação cívica
# ## Módulo 1: Por dentro do python
#
# ### Aula 3: Estrutura de controle

# %%
sg_partido = ['PSOL']

# %%
sg_partido_letra_p = []
sg_partido_letra_nao_definida = []

# %%
if sg_partido[0][0] == 'P' : # nessa linha estamos identificando o 1º item da lista
    sg_partido_letra_p.append(sg_partido[0])
else:
    sg_partido_letra_nao_definida.append(sg_partido[0])

# %%
print(f'Os partidos cujas as siglas iniciam com a letra P são: {sg_partido_letra_p}.')
print(f'Os partidos cujas as siglas não iniciam com a letra P são: {sg_partido_letra_nao_definida}.')
# Out:
# Os partidos cujas as siglas iniciam com a letra P são: ['PSOL'].
# Os partidos cujas as siglas não iniciam com a letra P são: [].

# %% [markdown]
# ### Nesse segundo exemplo, classificaremos o item do dicionário em um dos seguintes grupos:
#
# * 18-24 anos
# * 25-34 anos
# * 35-44 anos
# * 45-54 anos
# * 55-64 anos
# * acima 64 anos

# %%
candidatura = {'DT_GERACAO': '13/05/2023',
 'HH_GERACAO': '19:32:48',
 'ANO_ELEICAO': 2022,
 'CD_TIPO_ELEICAO': 2,
 'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
 'NR_TURNO': 1,
 'CD_ELEICAO': 546,
 'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
 'DT_ELEICAO': '02/10/2022',
 'TP_ABRANGENCIA': 'ESTADUAL',
 'SG_UF': 'PA',
 'SG_UE': 'PA',
 'NM_UE': 'PARÁ',
 'CD_CARGO': 6,
 'DS_CARGO': 'DEPUTADO FEDERAL',
 'SQ_CANDIDATO': 140001615571,
 'NR_CANDIDATO': 1456,
 'NM_CANDIDATO': 'PAULO EDUARDO MAESTRI BENGTSON',
 'NM_URNA_CANDIDATO': 'PAULO BENGTSON',
 'NM_SOCIAL_CANDIDATO': '#NULO#',
 'NR_CPF_CANDIDATO': 45417202215,
 'NM_EMAIL': 'NÃO DIVULGÁVEL',
 'CD_SITUACAO_CANDIDATURA': 12,
 'DS_SITUACAO_CANDIDATURA': 'APTO',
 'CD_DETALHE_SITUACAO_CAND': 2,
 'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
 'TP_AGREMIACAO': 'PARTIDO ISOLADO',
 'NR_PARTIDO': 14,
 'SG_PARTIDO': 'PTB',
 'NM_PARTIDO': 'PARTIDO TRABALHISTA BRASILEIRO',
 'NR_FEDERACAO': -1,
 'NM_FEDERACAO': '#NULO#',
 'SG_FEDERACAO': '#NULO#',
 'DS_COMPOSICAO_FEDERACAO': '#NULO#',
 'SQ_COLIGACAO': 140001681780,
 'NM_COLIGACAO': 'PARTIDO ISOLADO',
 'DS_COMPOSICAO_COLIGACAO': 'PTB',
 'CD_NACIONALIDADE': 1,
 'DS_NACIONALIDADE': 'BRASILEIRA NATA',
 'SG_UF_NASCIMENTO': 'BA',
 'CD_MUNICIPIO_NASCIMENTO': -3,
 'NM_MUNICIPIO_NASCIMENTO': 'VITÓRIA DA CONQUISTA',
 'DT_NASCIMENTO': '06/01/1974',
 'NR_IDADE_DATA_POSSE': 49.0,
 'NR_TITULO_ELEITORAL_CANDIDATO': 31043881376,
 'CD_GENERO': 2,
 'DS_GENERO': 'MASCULINO',
 'CD_GRAU_INSTRUCAO': 8,
 'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
 'CD_ESTADO_CIVIL': 1,
 'DS_ESTADO_CIVIL': 'SOLTEIRO(A)',
 'CD_COR_RACA': 1,
 'DS_COR_RACA': 'BRANCA',
 'CD_OCUPACAO': 277,
 'DS_OCUPACAO': 'DEPUTADO',
 'VR_DESPESA_MAX_CAMPANHA': 3176572.53,
 'CD_SIT_TOT_TURNO': 4,
 'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
 'ST_REELEICAO': 'S',
 'ST_DECLARAR_BENS': 'S',
 'NR_PROTOCOLO_CANDIDATURA': -1,
 'NR_PROCESSO': 6006641720226140000,
 'CD_SITUACAO_CANDIDATO_PLEITO': 2,
 'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
 'CD_SITUACAO_CANDIDATO_URNA': 2,
 'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
 'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
 'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
 'CD_SITUACAO_CANDIDATO_TOT': 2,
 'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
 'ST_PREST_CONTAS':'S'}
{'DT_GERACAO': '13/05/2023',
 'HH_GERACAO': '19:32:48',
 'ANO_ELEICAO': 2022,
 'CD_TIPO_ELEICAO': 2,
 'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
 'NR_TURNO': 1,
 'CD_ELEICAO': 546,
 'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
 'DT_ELEICAO': '02/10/2022',
 'TP_ABRANGENCIA': 'ESTADUAL',
 'SG_UF': 'PA',
 'SG_UE': 'PA',
 'NM_UE': 'PARÁ',
 'CD_CARGO': 6,
 'DS_CARGO': 'DEPUTADO FEDERAL',
 'SQ_CANDIDATO': 140001615571,
 'NR_CANDIDATO': 1456,
 'NM_CANDIDATO': 'PAULO EDUARDO MAESTRI BENGTSON',
 'NM_URNA_CANDIDATO': 'PAULO BENGTSON',
 'NM_SOCIAL_CANDIDATO': '#NULO#',
 'NR_CPF_CANDIDATO': 45417202215,
 'NM_EMAIL': 'NÃO DIVULGÁVEL',
 'CD_SITUACAO_CANDIDATURA': 12,
 'DS_SITUACAO_CANDIDATURA': 'APTO',
 'CD_DETALHE_SITUACAO_CAND': 2,
 'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
 'TP_AGREMIACAO': 'PARTIDO ISOLADO',
 'NR_PARTIDO': 14,
 'SG_PARTIDO': 'PTB',
 'NM_PARTIDO': 'PARTIDO TRABALHISTA BRASILEIRO',
 'NR_FEDERACAO': -1,
 'NM_FEDERACAO': '#NULO#',
 'SG_FEDERACAO': '#NULO#',
 'DS_COMPOSICAO_FEDERACAO': '#NULO#',
 'SQ_COLIGACAO': 140001681780,
 'NM_COLIGACAO': 'PARTIDO ISOLADO',
 'DS_COMPOSICAO_COLIGACAO': 'PTB',
 'CD_NACIONALIDADE': 1,
 'DS_NACIONALIDADE': 'BRASILEIRA NATA',
 'SG_UF_NASCIMENTO': 'BA',
 'CD_MUNICIPIO_NASCIMENTO': -3,
 'NM_MUNICIPIO_NASCIMENTO': 'VITÓRIA DA CONQUISTA',
 'DT_NASCIMENTO': '06/01/1974',
 'NR_IDADE_DATA_POSSE': 49.0,
 'NR_TITULO_ELEITORAL_CANDIDATO': 31043881376,
 'CD_GENERO': 2,
 'DS_GENERO': 'MASCULINO',
 'CD_GRAU_INSTRUCAO': 8,
 'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
 'CD_ESTADO_CIVIL': 1,
 'DS_ESTADO_CIVIL': 'SOLTEIRO(A)',
 'CD_COR_RACA': 1,
 'DS_COR_RACA': 'BRANCA',
 'CD_OCUPACAO': 277,
 'DS_OCUPACAO': 'DEPUTADO',
 'VR_DESPESA_MAX_CAMPANHA': 3176572.53,
 'CD_SIT_TOT_TURNO': 4,
 'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
 'ST_REELEICAO': 'S',
 'ST_DECLARAR_BENS': 'S',
 'NR_PROTOCOLO_CANDIDATURA': -1,
 'NR_PROCESSO': 6006641720226140000,
 'CD_SITUACAO_CANDIDATO_PLEITO': 2,
 'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
 'CD_SITUACAO_CANDIDATO_URNA': 2,
 'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
 'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
 'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
 'CD_SITUACAO_CANDIDATO_TOT': 2,
 'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
 'ST_PREST_CONTAS': 'S'}
# Out:
# {'DT_GERACAO': '13/05/2023',
#  'HH_GERACAO': '19:32:48',
#  'ANO_ELEICAO': 2022,
#  'CD_TIPO_ELEICAO': 2,
#  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
#  'NR_TURNO': 1,
#  'CD_ELEICAO': 546,
#  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
#  'DT_ELEICAO': '02/10/2022',
#  'TP_ABRANGENCIA': 'ESTADUAL',
#  'SG_UF': 'PA',
#  'SG_UE': 'PA',
#  'NM_UE': 'PARÁ',
#  'CD_CARGO': 6,
#  'DS_CARGO': 'DEPUTADO FEDERAL',
#  'SQ_CANDIDATO': 140001615571,
#  'NR_CANDIDATO': 1456,
#  'NM_CANDIDATO': 'PAULO EDUARDO MAESTRI BENGTSON',
#  'NM_URNA_CANDIDATO': 'PAULO BENGTSON',
#  'NM_SOCIAL_CANDIDATO': '#NULO#',
#  'NR_CPF_CANDIDATO': 45417202215,
#  'NM_EMAIL': 'NÃO DIVULGÁVEL',
#  'CD_SITUACAO_CANDIDATURA': 12,
#  'DS_SITUACAO_CANDIDATURA': 'APTO',
#  'CD_DETALHE_SITUACAO_CAND': 2,
#  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
#  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
#  'NR_PARTIDO': 14,
#  'SG_PARTIDO': 'PTB',
#  'NM_PARTIDO': 'PARTIDO TRABALHISTA BRASILEIRO',
#  'NR_FEDERACAO': -1,
# ...

# %%
#Construção das listas vazias com as idades

anos_18_24 = []
anos_25_34 = []
anos_35_44 = []
anos_45_54 = []
anos_55_64 = []
anos_acima_64 = []

# %%
#Junção de Estrutura de Controle + Operadores Lógicos

if candidatura['NR_IDADE_DATA_POSSE'] >= 18 and candidatura['NR_IDADE_DATA_POSSE'] <= 24:
    anos_18_24.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 25 and candidatura['NR_IDADE_DATA_POSSE'] <= 34:
    anos_25_34.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 35 and candidatura['NR_IDADE_DATA_POSSE'] <= 44:
    anos_35_44.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 45 and candidatura['NR_IDADE_DATA_POSSE'] <= 54:
    anos_45_54.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 55 and candidatura['NR_IDADE_DATA_POSSE'] <= 64:
    anos_55_64.append(candidatura['NM_CANDIDATO'])
else:
    anos_acima_64.append(candidatura['NM_CANDIDATO'])

# %%
print(f'Candidaturas por faixa etária:')
print(f'18-24 anos: {anos_18_24}')
print(f'25-34 anos: {anos_25_34}')
print(f'35-44 anos: {anos_35_44}')
print(f'45-54 anos: {anos_45_54}')
print(f'55-64 anos: {anos_55_64}')
print(f'acima 64 anos: {anos_acima_64}')
# Out:
# Candidaturas por faixa etária:
# 18-24 anos: []
# 25-34 anos: []
# 35-44 anos: []
# 45-54 anos: ['PAULO EDUARDO MAESTRI BENGTSON']
# 55-64 anos: []
# acima 64 anos: []

# %% [markdown]
# ### Aula 4: Estrutura de repetição

# %%
sg_partido = ['DEM', 'DC', 'PTB', 'REPUBLICANOS', 'PSL', 'PC do B', 'PTC',
       'CIDADANIA', 'PSOL', 'MDB', 'PT', 'PSB', 'AVANTE', 'PATRIOTA',
       'PSD', 'PDT', 'PRTB', 'PL', 'REDE', 'PODE', 'PSDB', 'PMN', 'PP',
       'PSC', 'SOLIDARIEDADE', 'PROS', 'PV', 'PCB', 'PMB', 'UP', 'NOVO',
       'PCO', 'PSTU']

# %%
#Criação da lista vazia

sg_partido_letra_p = []
sg_partido_letra_nao_definida = []

# %%
for sigla in sg_partido:

    if sigla[0] == 'P':
        sg_partido_letra_p.append(sigla)
    else:
        sg_partido_letra_nao_definida.append(sigla)
else:
    print('Atividade concluída')
# Out:
# Atividade concluída

# %%
print(f'Os partidos cujas as siglas iniciam com a letra P são: {sg_partido_letra_p}.')
# Out:
# Os partidos cujas as siglas iniciam com a letra P são: ['PTB', 'PSL', 'PC do B', 'PTC', 'PSOL', 'PT', 'PSB', 'PATRIOTA', 'PSD', 'PDT', 'PRTB', 'PL', 'PODE', 'PSDB', 'PMN', 'PP', 'PSC', 'PROS', 'PV', 'PCB', 'PMB', 'PCO', 'PSTU'].

# %%
print(f'Os partidos cujas as siglas não iniciam com a letra P são: {sg_partido_letra_nao_definida}.')
# Out:
# Os partidos cujas as siglas não iniciam com a letra P são: ['DEM', 'DC', 'REPUBLICANOS', 'CIDADANIA', 'MDB', 'AVANTE', 'REDE', 'SOLIDARIEDADE', 'UP', 'NOVO'].

# %%
candidaturas = [{'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 7,
  'DS_CARGO': 'DEPUTADO ESTADUAL',
  'SQ_CANDIDATO': 140001649400,
  'NR_CANDIDATO': 70123,
  'NM_CANDIDATO': 'HILTON ALVES DE AGUIAR',
  'NM_URNA_CANDIDATO': 'HILTON AGUIAR',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 15408078272,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 70,
  'SG_PARTIDO': 'AVANTE',
  'NM_PARTIDO': 'AVANTE',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001683277,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'AVANTE',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'MA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'CHAPADINHA',
  'DT_NASCIMENTO': '15/04/1963',
  'NR_IDADE_DATA_POSSE': 59.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 14328911376,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 6,
  'DS_GRAU_INSTRUCAO': 'ENSINO MÉDIO COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 1,
  'DS_COR_RACA': 'BRANCA',
  'CD_OCUPACAO': 257,
  'DS_OCUPACAO': 'EMPRESÁRIO',
  'VR_DESPESA_MAX_CAMPANHA': 1270629.01,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'S',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6008088820226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'S'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 7,
  'DS_CARGO': 'DEPUTADO ESTADUAL',
  'SQ_CANDIDATO': 140001611620,
  'NR_CANDIDATO': 11777,
  'NM_CANDIDATO': 'JOSE ALFREDO SILVA HAGE JUNIOR',
  'NM_URNA_CANDIDATO': 'JÚNIOR HAGE',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 43152619200,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 11,
  'SG_PARTIDO': 'PP',
  'NM_PARTIDO': 'PROGRESSISTAS',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001681582,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PP',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BELÉM',
  'DT_NASCIMENTO': '05/07/1973',
  'NR_IDADE_DATA_POSSE': 49.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 34545401392,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 1,
  'DS_ESTADO_CIVIL': 'SOLTEIRO(A)',
  'CD_COR_RACA': 1,
  'DS_COR_RACA': 'BRANCA',
  'CD_OCUPACAO': 131,
  'DS_OCUPACAO': 'ADVOGADO',
  'VR_DESPESA_MAX_CAMPANHA': 1270629.01,
  'CD_SIT_TOT_TURNO': 5,
  'DS_SIT_TOT_TURNO': 'SUPLENTE',
  'ST_REELEICAO': 'S',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6005239520226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'S'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 10,
  'DS_CARGO': '2º SUPLENTE',
  'SQ_CANDIDATO': 140001650189,
  'NR_CANDIDATO': 456,
  'NM_CANDIDATO': 'JAILSON DA COSTA ALVES',
  'NM_URNA_CANDIDATO': 'JAILSON DO MOJUÍ',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 32430132249,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 3,
  'DS_SITUACAO_CANDIDATURA': 'INAPTO',
  'CD_DETALHE_SITUACAO_CAND': 6,
  'DS_DETALHE_SITUACAO_CAND': 'RENÚNCIA',
  'TP_AGREMIACAO': 'FEDERAÇÃO',
  'NR_PARTIDO': 45,
  'SG_PARTIDO': 'PSDB',
  'NM_PARTIDO': 'PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA',
  'NR_FEDERACAO': 1,
  'NM_FEDERACAO': 'Federação PSDB Cidadania',
  'SG_FEDERACAO': 'PSDB/CIDADANIA',
  'DS_COMPOSICAO_FEDERACAO': 'PSDB/CIDADANIA',
  'SQ_COLIGACAO': 140001683304,
  'NM_COLIGACAO': 'FEDERAÇÃO',
  'DS_COMPOSICAO_COLIGACAO': 'PSDB/CIDADANIA',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'SANTARÉM',
  'DT_NASCIMENTO': '19/05/1968',
  'NR_IDADE_DATA_POSSE': 54.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 6568461376,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 7,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR INCOMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 1,
  'DS_COR_RACA': 'BRANCA',
  'CD_OCUPACAO': 999,
  'DS_OCUPACAO': 'OUTROS',
  'VR_DESPESA_MAX_CAMPANHA': -1.0,
  'CD_SIT_TOT_TURNO': -1,
  'DS_SIT_TOT_TURNO': '#NULO#',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6008365620226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': -1,
  'DS_SITUACAO_CANDIDATO_PLEITO': '#NULO#',
  'CD_SITUACAO_CANDIDATO_URNA': -1,
  'DS_SITUACAO_CANDIDATO_URNA': '#NULO#',
  'ST_CANDIDATO_INSERIDO_URNA': 'NÃO',
  'NM_TIPO_DESTINACAO_VOTOS': '#NULO#',
  'CD_SITUACAO_CANDIDATO_TOT': -1,
  'DS_SITUACAO_CANDIDATO_TOT': '#NULO#',
  'ST_PREST_CONTAS': 'N'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 6,
  'DS_CARGO': 'DEPUTADO FEDERAL',
  'SQ_CANDIDATO': 140001601483,
  'NR_CANDIDATO': 2030,
  'NM_CANDIDATO': 'JAVIER MARCELO CAHUANA VILLEGAS',
  'NM_URNA_CANDIDATO': 'JAVIER VILLEGAS',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 10944907253,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 20,
  'SG_PARTIDO': 'PSC',
  'NM_PARTIDO': 'PARTIDO SOCIAL CRISTÃO',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001681115,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PSC',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BELÉM',
  'DT_NASCIMENTO': '01/01/1960',
  'NR_IDADE_DATA_POSSE': 63.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 38518171317,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 301,
  'DS_OCUPACAO': 'DIRETOR DE EMPRESAS',
  'VR_DESPESA_MAX_CAMPANHA': 3176572.53,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6003117420226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'S'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 9,
  'DS_CARGO': '1º SUPLENTE',
  'SQ_CANDIDATO': 140001611664,
  'NR_CANDIDATO': 111,
  'NM_CANDIDATO': 'SILVIA ALBERTINA FERREIRA ABREU',
  'NM_URNA_CANDIDATO': 'SILVIA ABREU',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 71075895200,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 3,
  'DS_SITUACAO_CANDIDATURA': 'INAPTO',
  'CD_DETALHE_SITUACAO_CAND': 6,
  'DS_DETALHE_SITUACAO_CAND': 'RENÚNCIA',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 11,
  'SG_PARTIDO': 'PP',
  'NM_PARTIDO': 'PROGRESSISTAS',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001681585,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PP',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BELÉM',
  'DT_NASCIMENTO': '21/04/1981',
  'NR_IDADE_DATA_POSSE': 41.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 43062881317,
  'CD_GENERO': 4,
  'DS_GENERO': 'FEMININO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 1,
  'DS_ESTADO_CIVIL': 'SOLTEIRO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 999,
  'DS_OCUPACAO': 'OUTROS',
  'VR_DESPESA_MAX_CAMPANHA': -1.0,
  'CD_SIT_TOT_TURNO': -1,
  'DS_SIT_TOT_TURNO': '#NULO#',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6005438620226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': -1,
  'DS_SITUACAO_CANDIDATO_PLEITO': '#NULO#',
  'CD_SITUACAO_CANDIDATO_URNA': -1,
  'DS_SITUACAO_CANDIDATO_URNA': '#NULO#',
  'ST_CANDIDATO_INSERIDO_URNA': 'NÃO',
  'NM_TIPO_DESTINACAO_VOTOS': '#NULO#',
  'CD_SITUACAO_CANDIDATO_TOT': -1,
  'DS_SITUACAO_CANDIDATO_TOT': '#NULO#',
  'ST_PREST_CONTAS': 'N'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 6,
  'DS_CARGO': 'DEPUTADO FEDERAL',
  'SQ_CANDIDATO': 140001604454,
  'NR_CANDIDATO': 4040,
  'NM_CANDIDATO': 'JOSE FRANCISCO DE JESUS PANTOJA PEREIRA',
  'NM_URNA_CANDIDATO': 'ZÉ FRANCISCO',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 6911587204,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 40,
  'SG_PARTIDO': 'PSB',
  'NM_PARTIDO': 'PARTIDO SOCIALISTA BRASILEIRO',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001681244,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PSB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'CAMETÁ',
  'DT_NASCIMENTO': '15/11/1954',
  'NR_IDADE_DATA_POSSE': 68.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 11020501341,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 2,
  'DS_COR_RACA': 'PRETA',
  'CD_OCUPACAO': 291,
  'DS_OCUPACAO': 'OCUPANTE DE CARGO EM COMISSÃO',
  'VR_DESPESA_MAX_CAMPANHA': 3176572.53,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6004242820226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'S'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 7,
  'DS_CARGO': 'DEPUTADO ESTADUAL',
  'SQ_CANDIDATO': 140001677157,
  'NR_CANDIDATO': 14144,
  'NM_CANDIDATO': 'CELSO EMIDIO TORRES DE MORAES',
  'NM_URNA_CANDIDATO': 'CELSO DO BANCO',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 31964028272,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 14,
  'SG_PARTIDO': 'PTB',
  'NM_PARTIDO': 'PARTIDO TRABALHISTA BRASILEIRO',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001684130,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PTB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BRAGANÇA',
  'DT_NASCIMENTO': '09/12/1970',
  'NR_IDADE_DATA_POSSE': 52.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 26418531333,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 395,
  'DS_OCUPACAO': 'BANCÁRIO E ECONOMIÁRIO',
  'VR_DESPESA_MAX_CAMPANHA': 1270629.01,
  'CD_SIT_TOT_TURNO': 5,
  'DS_SIT_TOT_TURNO': 'SUPLENTE',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6010513220226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'N'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 7,
  'DS_CARGO': 'DEPUTADO ESTADUAL',
  'SQ_CANDIDATO': 140001677328,
  'NR_CANDIDATO': 35005,
  'NM_CANDIDATO': 'AZAEL FERREIRA MASCARENHAS',
  'NM_URNA_CANDIDATO': 'AZAEL MASCARENHAS',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 31968830278,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 35,
  'SG_PARTIDO': 'PMB',
  'NM_PARTIDO': 'PARTIDO DA MULHER BRASILEIRA',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001684139,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PMB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'ABAETETUBA',
  'DT_NASCIMENTO': '28/03/1964',
  'NR_IDADE_DATA_POSSE': 58.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 15238762283,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 4,
  'DS_GRAU_INSTRUCAO': 'ENSINO FUNDAMENTAL COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 169,
  'DS_OCUPACAO': 'COMERCIANTE',
  'VR_DESPESA_MAX_CAMPANHA': 1270629.01,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'N',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6012808920226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'S'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 7,
  'DS_CARGO': 'DEPUTADO ESTADUAL',
  'SQ_CANDIDATO': 140001677324,
  'NR_CANDIDATO': 35193,
  'NM_CANDIDATO': 'CARLOS CÉZAR ARAÚJO NOGUEIRA',
  'NM_URNA_CANDIDATO': 'BOMBEIRO CÉZAR NOGUEIRA',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 72282207220,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 35,
  'SG_PARTIDO': 'PMB',
  'NM_PARTIDO': 'PARTIDO DA MULHER BRASILEIRA',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001684139,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PMB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'VIGIA',
  'DT_NASCIMENTO': '31/07/1982',
  'NR_IDADE_DATA_POSSE': 40.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 37524971368,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 1,
  'DS_COR_RACA': 'BRANCA',
  'CD_OCUPACAO': 258,
  'DS_OCUPACAO': 'BOMBEIRO MILITAR',
  'VR_DESPESA_MAX_CAMPANHA': 1270629.01,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'N',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6010773020226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'N'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 6,
  'DS_CARGO': 'DEPUTADO FEDERAL',
  'SQ_CANDIDATO': 140001677537,
  'NR_CANDIDATO': 3533,
  'NM_CANDIDATO': 'LUCIA HELENA DO SOCORRO DA SILVA LOPES',
  'NM_URNA_CANDIDATO': 'NEIDE DA SAÚDE',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 36169820225,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 3,
  'DS_SITUACAO_CANDIDATURA': 'INAPTO',
  'CD_DETALHE_SITUACAO_CAND': 14,
  'DS_DETALHE_SITUACAO_CAND': 'INDEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 35,
  'SG_PARTIDO': 'PMB',
  'NM_PARTIDO': 'PARTIDO DA MULHER BRASILEIRA',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001684150,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PMB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BELÉM',
  'DT_NASCIMENTO': '19/12/1961',
  'NR_IDADE_DATA_POSSE': 61.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 13033221309,
  'CD_GENERO': 4,
  'DS_GENERO': 'FEMININO',
  'CD_GRAU_INSTRUCAO': 3,
  'DS_GRAU_INSTRUCAO': 'ENSINO FUNDAMENTAL INCOMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 2,
  'DS_COR_RACA': 'PRETA',
  'CD_OCUPACAO': 999,
  'DS_OCUPACAO': 'OUTROS',
  'VR_DESPESA_MAX_CAMPANHA': 3176572.53,
  'CD_SIT_TOT_TURNO': -1,
  'DS_SIT_TOT_TURNO': '#NULO#',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6011128720226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': -1,
  'DS_SITUACAO_CANDIDATO_PLEITO': '#NULO#',
  'CD_SITUACAO_CANDIDATO_URNA': -1,
  'DS_SITUACAO_CANDIDATO_URNA': '#NULO#',
  'ST_CANDIDATO_INSERIDO_URNA': 'NÃO',
  'NM_TIPO_DESTINACAO_VOTOS': '#NULO#',
  'CD_SITUACAO_CANDIDATO_TOT': -1,
  'DS_SITUACAO_CANDIDATO_TOT': '#NULO#',
  'ST_PREST_CONTAS': 'N'}]

# %%
anos_18_24 = []
anos_25_34 = []
anos_35_44 = []
anos_45_54 = []
anos_55_64 = []
anos_acima_64 = []

# %%
if candidatura['NR_IDADE_DATA_POSSE'] >= 18 and candidatura['NR_IDADE_DATA_POSSE'] <= 24:
    anos_18_24.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 25 and candidatura['NR_IDADE_DATA_POSSE'] <= 34:
    anos_25_34.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 35 and candidatura['NR_IDADE_DATA_POSSE'] <= 44:
    anos_35_44.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 45 and candidatura['NR_IDADE_DATA_POSSE'] <= 54:
    anos_45_54.append(candidatura['NM_CANDIDATO'])
elif candidatura['NR_IDADE_DATA_POSSE'] >= 55 and candidatura['NR_IDADE_DATA_POSSE'] <= 64:
    anos_55_64.append(candidatura['NM_CANDIDATO'])
else:
    anos_acima_64.append(candidatura['NM_CANDIDATO'])

# %%
print(f'Candidaturas por faixa etária:')
print(f'18-24 anos: {anos_18_24}')
print(f'25-34 anos: {anos_25_34}')
print(f'35-44 anos: {anos_35_44}')
print(f'45-54 anos: {anos_45_54}')
print(f'55-64 anos: {anos_55_64}')
print(f'acima 64 anos: {anos_acima_64}')
# Out:
# Candidaturas por faixa etária:
# 18-24 anos: []
# 25-34 anos: []
# 35-44 anos: []
# 45-54 anos: ['PAULO EDUARDO MAESTRI BENGTSON']
# 55-64 anos: []
# acima 64 anos: []

# %% [markdown]
# ##Desafio
#
# Usando o mesmo dicionário do exercício anterior. Agrupe as candidaturas em "feminino" e "masculino" usando a chave "DS_GENERO".

# %%
candidaturas_2 = [{'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 7,
  'DS_CARGO': 'DEPUTADO ESTADUAL',
  'SQ_CANDIDATO': 140001649400,
  'NR_CANDIDATO': 70123,
  'NM_CANDIDATO': 'HILTON ALVES DE AGUIAR',
  'NM_URNA_CANDIDATO': 'HILTON AGUIAR',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 15408078272,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 70,
  'SG_PARTIDO': 'AVANTE',
  'NM_PARTIDO': 'AVANTE',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001683277,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'AVANTE',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'MA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'CHAPADINHA',
  'DT_NASCIMENTO': '15/04/1963',
  'NR_IDADE_DATA_POSSE': 59.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 14328911376,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 6,
  'DS_GRAU_INSTRUCAO': 'ENSINO MÉDIO COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 1,
  'DS_COR_RACA': 'BRANCA',
  'CD_OCUPACAO': 257,
  'DS_OCUPACAO': 'EMPRESÁRIO',
  'VR_DESPESA_MAX_CAMPANHA': 1270629.01,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'S',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6008088820226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'S'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 7,
  'DS_CARGO': 'DEPUTADO ESTADUAL',
  'SQ_CANDIDATO': 140001611620,
  'NR_CANDIDATO': 11777,
  'NM_CANDIDATO': 'JOSE ALFREDO SILVA HAGE JUNIOR',
  'NM_URNA_CANDIDATO': 'JÚNIOR HAGE',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 43152619200,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 11,
  'SG_PARTIDO': 'PP',
  'NM_PARTIDO': 'PROGRESSISTAS',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001681582,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PP',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BELÉM',
  'DT_NASCIMENTO': '05/07/1973',
  'NR_IDADE_DATA_POSSE': 49.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 34545401392,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 1,
  'DS_ESTADO_CIVIL': 'SOLTEIRO(A)',
  'CD_COR_RACA': 1,
  'DS_COR_RACA': 'BRANCA',
  'CD_OCUPACAO': 131,
  'DS_OCUPACAO': 'ADVOGADO',
  'VR_DESPESA_MAX_CAMPANHA': 1270629.01,
  'CD_SIT_TOT_TURNO': 5,
  'DS_SIT_TOT_TURNO': 'SUPLENTE',
  'ST_REELEICAO': 'S',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6005239520226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'S'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 10,
  'DS_CARGO': '2º SUPLENTE',
  'SQ_CANDIDATO': 140001650189,
  'NR_CANDIDATO': 456,
  'NM_CANDIDATO': 'JAILSON DA COSTA ALVES',
  'NM_URNA_CANDIDATO': 'JAILSON DO MOJUÍ',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 32430132249,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 3,
  'DS_SITUACAO_CANDIDATURA': 'INAPTO',
  'CD_DETALHE_SITUACAO_CAND': 6,
  'DS_DETALHE_SITUACAO_CAND': 'RENÚNCIA',
  'TP_AGREMIACAO': 'FEDERAÇÃO',
  'NR_PARTIDO': 45,
  'SG_PARTIDO': 'PSDB',
  'NM_PARTIDO': 'PARTIDO DA SOCIAL DEMOCRACIA BRASILEIRA',
  'NR_FEDERACAO': 1,
  'NM_FEDERACAO': 'Federação PSDB Cidadania',
  'SG_FEDERACAO': 'PSDB/CIDADANIA',
  'DS_COMPOSICAO_FEDERACAO': 'PSDB/CIDADANIA',
  'SQ_COLIGACAO': 140001683304,
  'NM_COLIGACAO': 'FEDERAÇÃO',
  'DS_COMPOSICAO_COLIGACAO': 'PSDB/CIDADANIA',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'SANTARÉM',
  'DT_NASCIMENTO': '19/05/1968',
  'NR_IDADE_DATA_POSSE': 54.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 6568461376,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 7,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR INCOMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 1,
  'DS_COR_RACA': 'BRANCA',
  'CD_OCUPACAO': 999,
  'DS_OCUPACAO': 'OUTROS',
  'VR_DESPESA_MAX_CAMPANHA': -1.0,
  'CD_SIT_TOT_TURNO': -1,
  'DS_SIT_TOT_TURNO': '#NULO#',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6008365620226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': -1,
  'DS_SITUACAO_CANDIDATO_PLEITO': '#NULO#',
  'CD_SITUACAO_CANDIDATO_URNA': -1,
  'DS_SITUACAO_CANDIDATO_URNA': '#NULO#',
  'ST_CANDIDATO_INSERIDO_URNA': 'NÃO',
  'NM_TIPO_DESTINACAO_VOTOS': '#NULO#',
  'CD_SITUACAO_CANDIDATO_TOT': -1,
  'DS_SITUACAO_CANDIDATO_TOT': '#NULO#',
  'ST_PREST_CONTAS': 'N'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 6,
  'DS_CARGO': 'DEPUTADO FEDERAL',
  'SQ_CANDIDATO': 140001601483,
  'NR_CANDIDATO': 2030,
  'NM_CANDIDATO': 'JAVIER MARCELO CAHUANA VILLEGAS',
  'NM_URNA_CANDIDATO': 'JAVIER VILLEGAS',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 10944907253,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 20,
  'SG_PARTIDO': 'PSC',
  'NM_PARTIDO': 'PARTIDO SOCIAL CRISTÃO',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001681115,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PSC',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BELÉM',
  'DT_NASCIMENTO': '01/01/1960',
  'NR_IDADE_DATA_POSSE': 63.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 38518171317,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 301,
  'DS_OCUPACAO': 'DIRETOR DE EMPRESAS',
  'VR_DESPESA_MAX_CAMPANHA': 3176572.53,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6003117420226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'S'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 9,
  'DS_CARGO': '1º SUPLENTE',
  'SQ_CANDIDATO': 140001611664,
  'NR_CANDIDATO': 111,
  'NM_CANDIDATO': 'SILVIA ALBERTINA FERREIRA ABREU',
  'NM_URNA_CANDIDATO': 'SILVIA ABREU',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 71075895200,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 3,
  'DS_SITUACAO_CANDIDATURA': 'INAPTO',
  'CD_DETALHE_SITUACAO_CAND': 6,
  'DS_DETALHE_SITUACAO_CAND': 'RENÚNCIA',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 11,
  'SG_PARTIDO': 'PP',
  'NM_PARTIDO': 'PROGRESSISTAS',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001681585,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PP',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BELÉM',
  'DT_NASCIMENTO': '21/04/1981',
  'NR_IDADE_DATA_POSSE': 41.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 43062881317,
  'CD_GENERO': 4,
  'DS_GENERO': 'FEMININO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 1,
  'DS_ESTADO_CIVIL': 'SOLTEIRO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 999,
  'DS_OCUPACAO': 'OUTROS',
  'VR_DESPESA_MAX_CAMPANHA': -1.0,
  'CD_SIT_TOT_TURNO': -1,
  'DS_SIT_TOT_TURNO': '#NULO#',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6005438620226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': -1,
  'DS_SITUACAO_CANDIDATO_PLEITO': '#NULO#',
  'CD_SITUACAO_CANDIDATO_URNA': -1,
  'DS_SITUACAO_CANDIDATO_URNA': '#NULO#',
  'ST_CANDIDATO_INSERIDO_URNA': 'NÃO',
  'NM_TIPO_DESTINACAO_VOTOS': '#NULO#',
  'CD_SITUACAO_CANDIDATO_TOT': -1,
  'DS_SITUACAO_CANDIDATO_TOT': '#NULO#',
  'ST_PREST_CONTAS': 'N'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 6,
  'DS_CARGO': 'DEPUTADO FEDERAL',
  'SQ_CANDIDATO': 140001604454,
  'NR_CANDIDATO': 4040,
  'NM_CANDIDATO': 'JOSE FRANCISCO DE JESUS PANTOJA PEREIRA',
  'NM_URNA_CANDIDATO': 'ZÉ FRANCISCO',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 6911587204,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 40,
  'SG_PARTIDO': 'PSB',
  'NM_PARTIDO': 'PARTIDO SOCIALISTA BRASILEIRO',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001681244,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PSB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'CAMETÁ',
  'DT_NASCIMENTO': '15/11/1954',
  'NR_IDADE_DATA_POSSE': 68.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 11020501341,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 2,
  'DS_COR_RACA': 'PRETA',
  'CD_OCUPACAO': 291,
  'DS_OCUPACAO': 'OCUPANTE DE CARGO EM COMISSÃO',
  'VR_DESPESA_MAX_CAMPANHA': 3176572.53,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6004242820226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'S'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 7,
  'DS_CARGO': 'DEPUTADO ESTADUAL',
  'SQ_CANDIDATO': 140001677157,
  'NR_CANDIDATO': 14144,
  'NM_CANDIDATO': 'CELSO EMIDIO TORRES DE MORAES',
  'NM_URNA_CANDIDATO': 'CELSO DO BANCO',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 31964028272,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 14,
  'SG_PARTIDO': 'PTB',
  'NM_PARTIDO': 'PARTIDO TRABALHISTA BRASILEIRO',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001684130,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PTB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BRAGANÇA',
  'DT_NASCIMENTO': '09/12/1970',
  'NR_IDADE_DATA_POSSE': 52.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 26418531333,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 395,
  'DS_OCUPACAO': 'BANCÁRIO E ECONOMIÁRIO',
  'VR_DESPESA_MAX_CAMPANHA': 1270629.01,
  'CD_SIT_TOT_TURNO': 5,
  'DS_SIT_TOT_TURNO': 'SUPLENTE',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6010513220226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'N'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 7,
  'DS_CARGO': 'DEPUTADO ESTADUAL',
  'SQ_CANDIDATO': 140001677328,
  'NR_CANDIDATO': 35005,
  'NM_CANDIDATO': 'AZAEL FERREIRA MASCARENHAS',
  'NM_URNA_CANDIDATO': 'AZAEL MASCARENHAS',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 31968830278,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 35,
  'SG_PARTIDO': 'PMB',
  'NM_PARTIDO': 'PARTIDO DA MULHER BRASILEIRA',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001684139,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PMB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'ABAETETUBA',
  'DT_NASCIMENTO': '28/03/1964',
  'NR_IDADE_DATA_POSSE': 58.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 15238762283,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 4,
  'DS_GRAU_INSTRUCAO': 'ENSINO FUNDAMENTAL COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 3,
  'DS_COR_RACA': 'PARDA',
  'CD_OCUPACAO': 169,
  'DS_OCUPACAO': 'COMERCIANTE',
  'VR_DESPESA_MAX_CAMPANHA': 1270629.01,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'N',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6012808920226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'S'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 7,
  'DS_CARGO': 'DEPUTADO ESTADUAL',
  'SQ_CANDIDATO': 140001677324,
  'NR_CANDIDATO': 35193,
  'NM_CANDIDATO': 'CARLOS CÉZAR ARAÚJO NOGUEIRA',
  'NM_URNA_CANDIDATO': 'BOMBEIRO CÉZAR NOGUEIRA',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 72282207220,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 12,
  'DS_SITUACAO_CANDIDATURA': 'APTO',
  'CD_DETALHE_SITUACAO_CAND': 2,
  'DS_DETALHE_SITUACAO_CAND': 'DEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 35,
  'SG_PARTIDO': 'PMB',
  'NM_PARTIDO': 'PARTIDO DA MULHER BRASILEIRA',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001684139,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PMB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'VIGIA',
  'DT_NASCIMENTO': '31/07/1982',
  'NR_IDADE_DATA_POSSE': 40.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 37524971368,
  'CD_GENERO': 2,
  'DS_GENERO': 'MASCULINO',
  'CD_GRAU_INSTRUCAO': 8,
  'DS_GRAU_INSTRUCAO': 'SUPERIOR COMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 1,
  'DS_COR_RACA': 'BRANCA',
  'CD_OCUPACAO': 258,
  'DS_OCUPACAO': 'BOMBEIRO MILITAR',
  'VR_DESPESA_MAX_CAMPANHA': 1270629.01,
  'CD_SIT_TOT_TURNO': 4,
  'DS_SIT_TOT_TURNO': 'NÃO ELEITO',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'N',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6010773020226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': 2,
  'DS_SITUACAO_CANDIDATO_PLEITO': 'DEFERIDO',
  'CD_SITUACAO_CANDIDATO_URNA': 2,
  'DS_SITUACAO_CANDIDATO_URNA': 'DEFERIDO',
  'ST_CANDIDATO_INSERIDO_URNA': 'SIM',
  'NM_TIPO_DESTINACAO_VOTOS': 'Válido',
  'CD_SITUACAO_CANDIDATO_TOT': 2,
  'DS_SITUACAO_CANDIDATO_TOT': 'Deferido',
  'ST_PREST_CONTAS': 'N'},
 {'DT_GERACAO': '13/05/2023',
  'HH_GERACAO': '19:32:48',
  'ANO_ELEICAO': 2022,
  'CD_TIPO_ELEICAO': 2,
  'NM_TIPO_ELEICAO': 'ELEIÇÃO ORDINÁRIA',
  'NR_TURNO': 1,
  'CD_ELEICAO': 546,
  'DS_ELEICAO': 'Eleições Gerais Estaduais 2022',
  'DT_ELEICAO': '02/10/2022',
  'TP_ABRANGENCIA': 'ESTADUAL',
  'SG_UF': 'PA',
  'SG_UE': 'PA',
  'NM_UE': 'PARÁ',
  'CD_CARGO': 6,
  'DS_CARGO': 'DEPUTADO FEDERAL',
  'SQ_CANDIDATO': 140001677537,
  'NR_CANDIDATO': 3533,
  'NM_CANDIDATO': 'LUCIA HELENA DO SOCORRO DA SILVA LOPES',
  'NM_URNA_CANDIDATO': 'NEIDE DA SAÚDE',
  'NM_SOCIAL_CANDIDATO': '#NULO#',
  'NR_CPF_CANDIDATO': 36169820225,
  'NM_EMAIL': 'NÃO DIVULGÁVEL',
  'CD_SITUACAO_CANDIDATURA': 3,
  'DS_SITUACAO_CANDIDATURA': 'INAPTO',
  'CD_DETALHE_SITUACAO_CAND': 14,
  'DS_DETALHE_SITUACAO_CAND': 'INDEFERIDO',
  'TP_AGREMIACAO': 'PARTIDO ISOLADO',
  'NR_PARTIDO': 35,
  'SG_PARTIDO': 'PMB',
  'NM_PARTIDO': 'PARTIDO DA MULHER BRASILEIRA',
  'NR_FEDERACAO': -1,
  'NM_FEDERACAO': '#NULO#',
  'SG_FEDERACAO': '#NULO#',
  'DS_COMPOSICAO_FEDERACAO': '#NULO#',
  'SQ_COLIGACAO': 140001684150,
  'NM_COLIGACAO': 'PARTIDO ISOLADO',
  'DS_COMPOSICAO_COLIGACAO': 'PMB',
  'CD_NACIONALIDADE': 1,
  'DS_NACIONALIDADE': 'BRASILEIRA NATA',
  'SG_UF_NASCIMENTO': 'PA',
  'CD_MUNICIPIO_NASCIMENTO': -3,
  'NM_MUNICIPIO_NASCIMENTO': 'BELÉM',
  'DT_NASCIMENTO': '19/12/1961',
  'NR_IDADE_DATA_POSSE': 61.0,
  'NR_TITULO_ELEITORAL_CANDIDATO': 13033221309,
  'CD_GENERO': 4,
  'DS_GENERO': 'FEMININO',
  'CD_GRAU_INSTRUCAO': 3,
  'DS_GRAU_INSTRUCAO': 'ENSINO FUNDAMENTAL INCOMPLETO',
  'CD_ESTADO_CIVIL': 3,
  'DS_ESTADO_CIVIL': 'CASADO(A)',
  'CD_COR_RACA': 2,
  'DS_COR_RACA': 'PRETA',
  'CD_OCUPACAO': 999,
  'DS_OCUPACAO': 'OUTROS',
  'VR_DESPESA_MAX_CAMPANHA': 3176572.53,
  'CD_SIT_TOT_TURNO': -1,
  'DS_SIT_TOT_TURNO': '#NULO#',
  'ST_REELEICAO': 'N',
  'ST_DECLARAR_BENS': 'S',
  'NR_PROTOCOLO_CANDIDATURA': -1,
  'NR_PROCESSO': 6011128720226140000,
  'CD_SITUACAO_CANDIDATO_PLEITO': -1,
  'DS_SITUACAO_CANDIDATO_PLEITO': '#NULO#',
  'CD_SITUACAO_CANDIDATO_URNA': -1,
  'DS_SITUACAO_CANDIDATO_URNA': '#NULO#',
  'ST_CANDIDATO_INSERIDO_URNA': 'NÃO',
  'NM_TIPO_DESTINACAO_VOTOS': '#NULO#',
  'CD_SITUACAO_CANDIDATO_TOT': -1,
  'DS_SITUACAO_CANDIDATO_TOT': '#NULO#',
  'ST_PREST_CONTAS': 'N'}]

# %%
feminino = []
masculino = []

for genero in candidaturas_2:

  if genero["DS_GENERO"] == "FEMININO":
    feminino.append(genero)
  else:
    genero["DS_GENERO"] == "MASCULINO"
    masculino.append(genero)

# %%
import pandas as pd


df = pd.DataFrame(candidaturas_2, columns = ['DS_GENERO','NM_CANDIDATO'])
print(df)
# Out:
#    DS_GENERO                             NM_CANDIDATO
# 0  MASCULINO                   HILTON ALVES DE AGUIAR
# 1  MASCULINO           JOSE ALFREDO SILVA HAGE JUNIOR
# 2  MASCULINO                   JAILSON DA COSTA ALVES
# 3  MASCULINO          JAVIER MARCELO CAHUANA VILLEGAS
# 4   FEMININO          SILVIA ALBERTINA FERREIRA ABREU
# 5  MASCULINO  JOSE FRANCISCO DE JESUS PANTOJA PEREIRA
# 6  MASCULINO            CELSO EMIDIO TORRES DE MORAES
# 7  MASCULINO               AZAEL FERREIRA MASCARENHAS
# 8  MASCULINO             CARLOS CÉZAR ARAÚJO NOGUEIRA
# 9   FEMININO   LUCIA HELENA DO SOCORRO DA SILVA LOPES
