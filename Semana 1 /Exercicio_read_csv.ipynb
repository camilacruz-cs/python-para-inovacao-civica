# %% [markdown]
# <a href="https://colab.research.google.com/github/camilacruz-cs/python-para-inovacao-civica/blob/main/semana_1_exercicio_read_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Escola de Dados - Python para inovação cívica
# ### Módulo 1: Por dentro do python

# %% [markdown]
# ## Aula 6 - Método read_csv
# ### Instalaremos todos os pacotes que usaremos nesse módulo; Pandas, Matplotlib, Numpy, Jupiter Widgets e Pandas Profiling.

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install ipywidgets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 17.5 MB/s eta 0:00:00
# ...

# %%
pip install pandas-profiling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.0/353.0 kB 28.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 11.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 49.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 27.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 kB 39.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 80.0 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=e72ae9a7cbe9dc9050c92193395afaf41cad15baeaff6d49079fdad54c49359c
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# ...

# %%
import pandas as pd

# %%
#Atribuindo a variável 'candidaturas_ap' o arquivo .csv
candidaturas_ap = pd.read_csv('/content/consulta_cand_2022_AP.csv', sep=';', encoding='latin_1')

# %%
# o comando abaixo retira a limitação da quantidade de colunas impressa na tela

pd.options.display.max_columns = None

# %%
#cABEÇALHOS
candidaturas_ap.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  25/06/2023   19:31:27         2022                2  ELEIÇÃO ORDINÁRIA
# 1  25/06/2023   19:31:27         2022                2  ELEIÇÃO ORDINÁRIA
# 2  25/06/2023   19:31:27         2022                2  ELEIÇÃO ORDINÁRIA
# 3  25/06/2023   19:31:27         2022                2  ELEIÇÃO ORDINÁRIA
# 4  25/06/2023   19:31:27         2022                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 1         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 2         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 3         1         546  Eleições Gerais Estaduais 2022  02/10/2022
# 4         1         546  Eleições Gerais Estaduais 2022  02/10/2022
#
#   TP_ABRANGENCIA SG_UF SG_UE  NM_UE  CD_CARGO           DS_CARGO  \
# ...

# %%
#Tamanho do arquivo utilizado.
candidaturas_ap.shape
# Out:
# (557, 75)
