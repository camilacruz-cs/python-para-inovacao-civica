# %% [markdown]
# <a href="https://colab.research.google.com/github/camilacruz-cs/python-para-inovacao-civica/blob/main/semana2_desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Limpeza de dados e estatística descritiva
#
# Neste desafio colocaremos em prática alguns conceitos apresentado nas aulas. Para isso, usaremos o conjunto de dados [Prestação de contas eleitorais - 2020](https://dadosabertos.tse.jus.br/dataset/prestacao-de-contas-eleitorais-2020) disponível no Portal de Dados Abertos do Tribunal Superior Eleitoral.
#
# Os dados também podem ser encontrados na pasta "Dados" deste repositório.
#
# Preencha as lacunas abaixo para completar o desafio.

# %% [markdown]
# # Importe os pacotes necessários

# %%
import pandas as pd
import numpy as np
#Correção, não adicionei a biblioteca matplot
import matplotlib.pyplot as plt

# %% [markdown]
# # Leia o arquivo "receitas_orgaos_partidarios_2020_NORTE.csv" que está na pasta dados desse repositório, usando o Pandas
#
# Na aula `1.10 - Outliers e valores faltantes`, vimos como utilizar o método `replace` para substituir valores em certos colunas do nosso dataframe e trocar o texto (string) `#NULO#` pela representação padrão do Pandas para valores nulos.
#
# Aqui, vamos utilizar um outro método, onde definimos quais strings serão considerados valores nulos já na importação do arquivo.
#
# Edite as células abaixo e inclua:
#
# * O nome do arquivo que queremos importar
# * O separador utilizado
# * Insira uma lista no parâmetro `na_values` que contenha o texto a ser ignorado.
#
# Experimente rodar os comandos primeiro sem e depois com o parâmetro `na_values`, então, compare a diferença. Observe, por exemplo, o campo `CD_CNAE_DOADOR`.

# %%
df_receita = pd.read_csv('/content/receitas_orgaos_partidarios_2020_NORTE.csv', sep=';')

df_receita.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6052 entries, 0 to 6051
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DT_GERACAO                   6052 non-null   object
#  1   HH_GERACAO                   6052 non-null   object
#  2   ANO_ELEICAO                  6052 non-null   int64
#  3   CD_TIPO_ELEICAO              6052 non-null   int64
#  4   NM_TIPO_ELEICAO              6052 non-null   object
#  5   TP_PRESTACAO_CONTAS          6052 non-null   object
#  6   DT_PRESTACAO_CONTAS          6052 non-null   object
#  7   SQ_PRESTADOR_CONTAS          6052 non-null   int64
#  8   CD_ESFERA_PARTIDARIA         6052 non-null   object
#  9   DS_ESFERA_PARTIDARIA         6052 non-null   object
#  10  SG_UF                        6052 non-null   object
#  11  CD_MUNICIPIO                 5043 non-null   float64
#  12  NM_MUNICIPIO                 5043 non-null   object
#  13  NR_CNPJ_PRESTADOR_CONTA      6052 non-null   int64
#  14  NR_PARTIDO                   6052 non-null   int64
#  15  SG_PARTIDO                   6052 non-null   object
#  16  NM_PARTIDO                   6052 non-null   object
#  17  CD_FONTE_RECEITA             6052 non-null   int64
#  18  DS_FONTE_RECEITA             6052 non-null   object
#  19  CD_ORIGEM_RECEITA            6052 non-null   int64
#  20  DS_ORIGEM_RECEITA            6052 non-null   object
#  21  CD_NATUREZA_RECEITA          6052 non-null   int64
#  22  DS_NATUREZA_RECEITA          6052 non-null   object
#  23  CD_ESPECIE_RECEITA           6052 non-null   int64
#  24  DS_ESPECIE_RECEITA           6052 non-null   object
#  25  CD_CNAE_DOADOR               3033 non-null   float64
#  26  DS_CNAE_DOADOR               3033 non-null   object
#  27  NR_CPF_CNPJ_DOADOR           6016 non-null   float64
#  28  NM_DOADOR                    6016 non-null   object
#  29  NM_DOADOR_RFB                6016 non-null   object
#  30  CD_ESFERA_PARTIDARIA_DOADOR  2071 non-null   object
#  31  DS_ESFERA_PARTIDARIA_DOADOR  2071 non-null   object
#  32  SG_UF_DOADOR                 3033 non-null   object
#  33  CD_MUNICIPIO_DOADOR          1092 non-null   float64
#  34  NM_MUNICIPIO_DOADOR          1092 non-null   object
#  35  SQ_CANDIDATO_DOADOR          886 non-null    float64
#  36  NR_CANDIDATO_DOADOR          962 non-null    float64
#  37  CD_CARGO_CANDIDATO_DOADOR    962 non-null    float64
#  38  DS_CARGO_CANDIDATO_DOADOR    962 non-null    object
#  39  NR_PARTIDO_DOADOR            3033 non-null   float64
#  40  SG_PARTIDO_DOADOR            3033 non-null   object
#  41  NM_PARTIDO_DOADOR            3033 non-null   object
#  42  NR_RECIBO_DOACAO             5623 non-null   object
#  43  NR_DOCUMENTO_DOACAO          3924 non-null   object
#  44  SQ_RECEITA                   6052 non-null   int64
#  45  DT_RECEITA                   6052 non-null   object
#  46  DS_RECEITA                   1933 non-null   object
#  47  VR_RECEITA                   6052 non-null   object
# dtypes: float64(8), int64(10), object(30)
# memory usage: 2.2+ MB

# %%
df = pd.read_csv('/content/receitas_orgaos_partidarios_2020_NORTE.csv',sep=';',na_values= '#NULO')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6052 entries, 0 to 6051
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DT_GERACAO                   6052 non-null   object
#  1   HH_GERACAO                   6052 non-null   object
#  2   ANO_ELEICAO                  6052 non-null   int64
#  3   CD_TIPO_ELEICAO              6052 non-null   int64
#  4   NM_TIPO_ELEICAO              6052 non-null   object
#  5   TP_PRESTACAO_CONTAS          6052 non-null   object
#  6   DT_PRESTACAO_CONTAS          6052 non-null   object
#  7   SQ_PRESTADOR_CONTAS          6052 non-null   int64
#  8   CD_ESFERA_PARTIDARIA         6052 non-null   object
#  9   DS_ESFERA_PARTIDARIA         6052 non-null   object
#  10  SG_UF                        6052 non-null   object
#  11  CD_MUNICIPIO                 5043 non-null   float64
#  12  NM_MUNICIPIO                 5043 non-null   object
#  13  NR_CNPJ_PRESTADOR_CONTA      6052 non-null   int64
#  14  NR_PARTIDO                   6052 non-null   int64
#  15  SG_PARTIDO                   6052 non-null   object
#  16  NM_PARTIDO                   6052 non-null   object
#  17  CD_FONTE_RECEITA             6052 non-null   int64
#  18  DS_FONTE_RECEITA             6052 non-null   object
#  19  CD_ORIGEM_RECEITA            6052 non-null   int64
#  20  DS_ORIGEM_RECEITA            6052 non-null   object
#  21  CD_NATUREZA_RECEITA          6052 non-null   int64
#  22  DS_NATUREZA_RECEITA          6052 non-null   object
#  23  CD_ESPECIE_RECEITA           6052 non-null   int64
#  24  DS_ESPECIE_RECEITA           6052 non-null   object
#  25  CD_CNAE_DOADOR               3033 non-null   float64
#  26  DS_CNAE_DOADOR               3033 non-null   object
#  27  NR_CPF_CNPJ_DOADOR           6016 non-null   float64
#  28  NM_DOADOR                    6016 non-null   object
#  29  NM_DOADOR_RFB                6016 non-null   object
#  30  CD_ESFERA_PARTIDARIA_DOADOR  2071 non-null   object
#  31  DS_ESFERA_PARTIDARIA_DOADOR  2071 non-null   object
#  32  SG_UF_DOADOR                 3033 non-null   object
#  33  CD_MUNICIPIO_DOADOR          1092 non-null   float64
#  34  NM_MUNICIPIO_DOADOR          1092 non-null   object
#  35  SQ_CANDIDATO_DOADOR          886 non-null    float64
#  36  NR_CANDIDATO_DOADOR          962 non-null    float64
#  37  CD_CARGO_CANDIDATO_DOADOR    962 non-null    float64
#  38  DS_CARGO_CANDIDATO_DOADOR    962 non-null    object
#  39  NR_PARTIDO_DOADOR            3033 non-null   float64
#  40  SG_PARTIDO_DOADOR            3033 non-null   object
#  41  NM_PARTIDO_DOADOR            3033 non-null   object
#  42  NR_RECIBO_DOACAO             5623 non-null   object
#  43  NR_DOCUMENTO_DOACAO          3924 non-null   object
#  44  SQ_RECEITA                   6052 non-null   int64
#  45  DT_RECEITA                   6052 non-null   object
#  46  DS_RECEITA                   1933 non-null   object
#  47  VR_RECEITA                   6052 non-null   object
# dtypes: float64(8), int64(10), object(30)
# memory usage: 2.2+ MB

# %% [markdown]
# # Filtre apenas os registros que sejam da prestação de contas final

# %%
# Primeiro vamos ver os valores únicos da coluna TP_PRESTACAO_CONTAS

df['TP_PRESTACAO_CONTAS'].unique()
# Out:
# array(['Final', 'Parcial', 'Relatório Financeiro',
#        'Regularização da Omissão'], dtype=object)

# %%
# O resultado deste comando nos diz que quantas linhas e colunas temos antes do filtro
df.shape
# Out:
# (6052, 48)

# %%
# Preencha o campo os espaços abaixo com o nome da coluna e o valor desejado para nosso filtro
df_final = df[df['TP_PRESTACAO_CONTAS'] == 'Final'].copy()

# %%
# Rode o comando shape no novo dataframe criado e confira se o número de linhas foi reduzido

df_final.shape
# Out:
# (5912, 49)

# %%
df_final.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0  13/05/2023   23:23:30         2020                2       Ordinária
# 1  13/05/2023   23:23:30         2020                2       Ordinária
# 2  13/05/2023   23:23:30         2020                2       Ordinária
# 3  13/05/2023   23:23:30         2020                2       Ordinária
# 4  13/05/2023   23:23:30         2020                2       Ordinária
#
#   TP_PRESTACAO_CONTAS DT_PRESTACAO_CONTAS  SQ_PRESTADOR_CONTAS  \
# 0               Final          25/12/2020           2021442465
# 1               Final          29/09/2021           2021442455
# 2               Final          14/05/2021           2021442514
# 3               Final          25/12/2020           2021442465
# 4               Final          24/12/2020           2021442457
#
#   CD_ESFERA_PARTIDARIA DS_ESFERA_PARTIDARIA  ... NR_PARTIDO_DOADOR  \
# 0                    M            Municipal  ...              15.0
# 1                    M            Municipal  ...              10.0
# 2                    M            Municipal  ...              25.0
# 3                    M            Municipal  ...              15.0
# 4                    M            Municipal  ...              11.0
#
#    SG_PARTIDO_DOADOR                 NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 0                MDB  Movimento Democrático Brasileiro  P15000406050AP000001A
# 1       REPUBLICANOS                      REPUBLICANOS  P10000406050AP000001A
# 2                DEM                        Democratas  P90000406050AP000010A
# 3                MDB  Movimento Democrático Brasileiro  P15000406050AP000002A
# 4                 PP                     PROGRESSISTAS  P11000406050AP000001A
#
#    NR_DOCUMENTO_DOACAO SQ_RECEITA  DT_RECEITA  \
# 0                  NaN   19516003  19/10/2020
# 1               850004   20034477  21/12/2020
# 2                  NaN   19877474  05/10/2020
# 3      614544000054449   19516004  14/11/2020
# 4    00000887169000105   19515403  14/10/2020
#
#                                           DS_RECEITA VR_RECEITA  TIPO_DOADOR
# 0  PRESTAÇÃO DE SERVIÇO DE ASSESSORIA CONTABIL E ...    1000,00     juridica
# 1                                                NaN      36,00     juridica
# 2                PRODUÇÃO E INSERCAO PARA RADIO E TV   15000,00     juridica
# 3                                                NaN  210000,00     juridica
# 4                                                NaN  482400,00     juridica
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Qual foi a maior doação de pessoa física e pessoa jurídica em cada estado?
#
# Vamos usar o método `value_counts` para não só listar cada valor único da coluna `CD_CNAE_DOADOR`, como também mostrar quantos registros temos em cada um.

# %%
# Preencha o nome da coluna abaixo
df_final['CD_CNAE_DOADOR'].value_counts()
# Out:
# 94928.0    2957
# 47814.0       2
# 59120.0       1
# 85996.0       1
# Name: CD_CNAE_DOADOR, dtype: int64

# %%
import pandas as pd

# %%
# Para ver os resultados em percentuais é fácil! Basta falarmos para o value_counts que queremos os resultados normalizados
df_final['CD_CNAE_DOADOR'].value_counts(normalize=True)
# Out:
# 94928.0    0.998649
# 47814.0    0.000675
# 59120.0    0.000338
# 85996.0    0.000338
# Name: CD_CNAE_DOADOR, dtype: float64

# %% [markdown]
# Se o doador for pessoa jurídica, temos seu respectivo código CNAE. Se for pessoa física, então temos o valor `-1`.
#
# Qual conclusão podemos tirar a respeito dos comandos acima?
#
# Escreva um **comentário** na célula abaixo com a resposta.

# %%
# Mais da metade dos registros são de pessoas juridicas, com o valor de 2957 pessoas.

# %% [markdown]
# Agora, vamos duplicar a coluna `CD_CNAE_DOADOR` e deixar esta nova coluna apenas com 2 categorias: física (representada pelo valor -1) ou jurídica (que vamos representar inicialmente com 1).

# %%
# Vamos criar uma nova coluna que seja uma cópia exata da coluna CD_CNAE_DOADOR
df_final['TIPO_DOADOR'] = df_final.loc[:,'CD_CNAE_DOADOR']

#Correção, no meu, eu não coloquei o loc

# %%
#Correção. Não havia colocado.
df_final['TIPO_DOADOR'] = df_final.loc[:, 'CD_CNAE_DOADOR'].replace(np.nan, -1)

# %%
df_final.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0  13/05/2023   23:23:30         2020                2       Ordinária
# 1  13/05/2023   23:23:30         2020                2       Ordinária
# 2  13/05/2023   23:23:30         2020                2       Ordinária
# 3  13/05/2023   23:23:30         2020                2       Ordinária
# 4  13/05/2023   23:23:30         2020                2       Ordinária
#
#   TP_PRESTACAO_CONTAS DT_PRESTACAO_CONTAS  SQ_PRESTADOR_CONTAS  \
# 0               Final          25/12/2020           2021442465
# 1               Final          29/09/2021           2021442455
# 2               Final          14/05/2021           2021442514
# 3               Final          25/12/2020           2021442465
# 4               Final          24/12/2020           2021442457
#
#   CD_ESFERA_PARTIDARIA DS_ESFERA_PARTIDARIA  ... NR_PARTIDO_DOADOR  \
# 0                    M            Municipal  ...              15.0
# 1                    M            Municipal  ...              10.0
# 2                    M            Municipal  ...              25.0
# 3                    M            Municipal  ...              15.0
# 4                    M            Municipal  ...              11.0
#
#    SG_PARTIDO_DOADOR                 NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 0                MDB  Movimento Democrático Brasileiro  P15000406050AP000001A
# 1       REPUBLICANOS                      REPUBLICANOS  P10000406050AP000001A
# 2                DEM                        Democratas  P90000406050AP000010A
# 3                MDB  Movimento Democrático Brasileiro  P15000406050AP000002A
# 4                 PP                     PROGRESSISTAS  P11000406050AP000001A
#
#    NR_DOCUMENTO_DOACAO SQ_RECEITA  DT_RECEITA  \
# 0                  NaN   19516003  19/10/2020
# 1               850004   20034477  21/12/2020
# 2                  NaN   19877474  05/10/2020
# 3      614544000054449   19516004  14/11/2020
# 4    00000887169000105   19515403  14/10/2020
#
#                                           DS_RECEITA VR_RECEITA  TIPO_DOADOR
# 0  PRESTAÇÃO DE SERVIÇO DE ASSESSORIA CONTABIL E ...    1000,00      94928.0
# 1                                                NaN      36,00      94928.0
# 2                PRODUÇÃO E INSERCAO PARA RADIO E TV   15000,00      94928.0
# 3                                                NaN  210000,00      94928.0
# 4                                                NaN  482400,00      94928.0
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Substituição condicional (conditional replacing)
#
# Agora, vamos usar o método where do pacote NumPy (carinhosamente chamado de np abaixo).
#
# Esta função recebe três parâmetros:
#
# * Uma condição: no nosso caso, queremos que filtrar as coluna do CNAE onde os valores sejam -1
# * Um valor: caso a condição acima seja verdadeira, qual valor deverá ser retornado?
# * Outro valor: se a condição for falsa, então, qual outro valor deverá ser retornado?

# %%
df_final['TIPO_DOADOR'] = np.where(df_final['CD_CNAE_DOADOR']==-1, 'fisica', 'juridica')

# %%
df_final.tail()
# Out:
#       DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 6047  13/05/2023   23:23:30         2020                2       Ordinária
# 6048  13/05/2023   23:23:30         2020                2       Ordinária
# 6049  13/05/2023   23:23:30         2020                2       Ordinária
# 6050  13/05/2023   23:23:30         2020                2       Ordinária
# 6051  13/05/2023   23:23:30         2020                2       Ordinária
#
#      TP_PRESTACAO_CONTAS DT_PRESTACAO_CONTAS  SQ_PRESTADOR_CONTAS  \
# 6047               Final          10/12/2020           1249052678
# 6048               Final          07/12/2020           1421049772
# 6049               Final          10/11/2021           1400324204
# 6050               Final          10/12/2020           1249052678
# 6051               Final          07/12/2020           1421049772
#
#      CD_ESFERA_PARTIDARIA DS_ESFERA_PARTIDARIA  ... NR_PARTIDO_DOADOR  \
# 6047                    M            Municipal  ...              65.0
# 6048                    M            Municipal  ...              65.0
# 6049                    M            Municipal  ...              10.0
# 6050                    M            Municipal  ...              65.0
# 6051                    M            Municipal  ...              65.0
#
#       SG_PARTIDO_DOADOR            NM_PARTIDO_DOADOR       NR_RECIBO_DOACAO  \
# 6047            PC do B  Partido Comunista do Brasil  P65000401023AC000001A
# 6048            PC do B  Partido Comunista do Brasil  P65000401082AC000001A
# 6049       REPUBLICANOS                 REPUBLICANOS  P10000401023AC000001A
# 6050            PC do B  Partido Comunista do Brasil  P65000401023AC000002A
# 6051            PC do B  Partido Comunista do Brasil  P65000401082AC000002A
#
#       NR_DOCUMENTO_DOACAO SQ_RECEITA  DT_RECEITA  \
# 6047                  NaN   17814394  28/10/2020
# 6048                  NaN   17434268  28/10/2020
# 6049                  NaN   20063362  05/11/2020
# 6050                  NaN   17814395  12/11/2020
# 6051                  NaN   17434269  12/11/2020
#
#                                              DS_RECEITA VR_RECEITA  \
# 6047  PRESTAÇÃO DE SERVIÇOS DE CONTABILIDADE PARA PR...     370,00
# 6048  PRESTAÇÃO DE SERVIÇOS DE CONTABILIDADE PARA PR...      37,00
# 6049                            HONORÁRIOS ADVOCATÍCIOS     800,00
# 6050                 PRESTAÇÃO DE SERVIÇOS ADVOCATÍCIOS     265,00
# 6051                 PRESTAÇÃO DE SERVIÇOS ADVOCATÍCIOS     265,00
#
#       TIPO_DOADOR
# 6047     juridica
# 6048     juridica
# 6049     juridica
# 6050     juridica
# 6051     juridica
#
# [5 rows x 49 columns]

# %% [markdown]
# ## Agrupando (group by)

# %%
#Correção. Não fiz essa etapa.

df_final['VR_RECEITA'] = df_final['VR_RECEITA'].replace(',', '.')

# %%
#Correção. Não fiz essa etapa.

df_final['VR_RECEITA'] = df_final['VR_RECEITA'].astype(float)

# %%
# Preencha abaixo primeiro uma lista com as 3 colunas que precisamos utilizar para responder à pergunta. E depois o nome das 2 colunas que precisamos agrupar.

df_final[['TIPO_DOADOR','SG_UF','VR_RECEITA']].groupby(by=['TIPO_DOADOR','SG_UF']).max()
# Out:
#                   VR_RECEITA
# TIPO_DOADOR SG_UF
# juridica    AC        960,00
#             AM         99,30
#             AP        986,00
#             PA       9900,00
#             RO       9502,40
#             RR        970,00
#             TO        995,94

# %%
# Para repetir o valor da coluna TIPO_DOADOR nas linhas, coloque o parâmetro as_index=False no método groupby do comando acima

df_final[['TIPO_DOADOR', 'CD_CNAE_DOADOR', 'TP_PRESTACAO_CONTAS']].groupby(by='TP_PRESTACAO_CONTAS', as_index=False).max()
# Out:
#   TP_PRESTACAO_CONTAS TIPO_DOADOR  CD_CNAE_DOADOR
# 0               Final    juridica         94928.0

# %% [markdown]
# ## Qual o total de doações recebidas por partido?

# %%
total_doacoes = df_final[['SG_PARTIDO','NM_PARTIDO','VR_RECEITA']].groupby(by=['SG_PARTIDO','NM_PARTIDO']).sum()
total_doacoes
# Out:
#                                                                                                VR_RECEITA
# SG_PARTIDO    NM_PARTIDO
# AVANTE        AVANTE                                    15000,00500,00750,00750,00500,001,205000,00500...
# CIDADANIA     Cidadania                                 150463,841500,0020,45800,00600,003000,00400,00...
# DC            Democracia Cristã                         24592,5155664,001500,00200,0055664,0024592,514...
# DEM           Democratas                                96000,0015000,00323,451250,005500,001250,00152...
# MDB           Movimento Democrático Brasileiro          1000,00210000,001000,001000,001000,001000,0011...
# NOVO          Partido Novo                              200,00100,00300,00240,00420,00120,00200,00100,...
# PATRIOTA      Patriota                                  700,001000,001500,009,802270,951,0039,5514,001...
# PC do B       Partido Comunista do Brasil               1000,00500,006000,0039000,00678,3010200,0045,5...
# PCB           Partido Comunista Brasileiro                                                 1800,004157,40
# PDT           Partido Democrático Trabalhista           100,00200000,00100000,0015000,0015000,00100000...
# PL            Partido Liberal                           200,00200,00200,00200,00200,00200,00200,00200,...
# PMB           Partido da Mulher Brasileira              3200,00600,00300,00500,00300,00300,00100000,00...
# PMN           Partido da Mobilização Nacional           135,00285,004000,00238,09238,09132,50500,00500...
# PODE          Podemos                                   500,00500,00500,00500,00500,00500,0030000,0010...
# PP            PROGRESSISTAS                             482400,005002,7437,3010157,086771,39158400,003...
# PROS          Partido Republicano da Ordem Social       15000,001250,00102212,0088781,00105000,0021991...
# PRTB          Partido Renovador Trabalhista Brasileiro  0,50250,001000,001302,004100,005000,0023,7451,...
# PSB           Partido Socialista Brasileiro             305000,00198190,8449,881500,00374323,545254,80...
# PSC           Partido Social Cristão                    2000,001000,001500,001500,001000,00184,20184,6...
# PSD           Partido Social Democrático                79,004900000,0079,004900000,0032,6515,001000,0...
# PSDB          Partido da Social Democracia Brasileira   6720,00100780,0023572,00125164,0070336,0056204...
# PSL           Partido Social Liberal                    3000,003000,00210000,00420000,00170000,0067000...
# PSOL          Partido Socialismo e Liberdade            31814,2331814,2331814,2331814,2314172,3524744,...
# PT            Partido dos Trabalhadores                 29000,0013000,0057000,0024000,00280,00280,0010...
# PTB           Partido Trabalhista Brasileiro            70000,0095471,8980096,30320385,19158706,393967...
# PTC           Partido Trabalhista Cristão               100000,001500,002000,004931,0019500,0030000,00...
# PV            Partido Verde                             15000,008400,009000,006000,006000,003168,55530...
# REDE          Rede Sustentabilidade                     855833,33460833,33750057,60511525,00421907,409...
# REPUBLICANOS  REPUBLICANOS                              36,0018,6580000,0036,0080,0086,0029,10625,0062...
# SOLIDARIEDADE Solidariedade                             35000,0060000,00210000,004000,005000,0090000,0...
# UP            Unidade Popular                                                3000,002500,006700,003000,00

# %% [markdown]
# ## Qual é o top 10?
#
# Crie um novo dataframe com os 10 partidos com mais doações. Você precisa primeiro ordenar os resultados e depois selecionar apenas os 10 primeiros.

# %%
#Fórmula correta.

total_doacoes_decrescente = total_doacoes.sort_values(by='VR_RECEITA',ascending=False)
total_doacoes_decrescente

#Minha fórmula
#df_final[['NM_PARTIDO_DOADOR','VR_RECEITA']].groupby(by='VR_RECEITA').sum().sort_values(by=0,ascending=False).head()
# Out:
#                                                                                                VR_RECEITA
# SG_PARTIDO    NM_PARTIDO
# DEM           Democratas                                96000,0015000,00323,451250,005500,001250,00152...
# REDE          Rede Sustentabilidade                     855833,33460833,33750057,60511525,00421907,409...
# PSD           Partido Social Democrático                79,004900000,0079,004900000,0032,6515,001000,0...
# PTB           Partido Trabalhista Brasileiro            70000,0095471,8980096,30320385,19158706,393967...
# PATRIOTA      Patriota                                  700,001000,001500,009,802270,951,0039,5514,001...
# PSDB          Partido da Social Democracia Brasileira   6720,00100780,0023572,00125164,0070336,0056204...
# PODE          Podemos                                   500,00500,00500,00500,00500,00500,0030000,0010...
# PP            PROGRESSISTAS                             482400,005002,7437,3010157,086771,39158400,003...
# REPUBLICANOS  REPUBLICANOS                              36,0018,6580000,0036,0080,0086,0029,10625,0062...
# SOLIDARIEDADE Solidariedade                             35000,0060000,00210000,004000,005000,0090000,0...
# PMB           Partido da Mulher Brasileira              3200,00600,00300,00500,00300,00300,00100000,00...
# PSOL          Partido Socialismo e Liberdade            31814,2331814,2331814,2331814,2314172,3524744,...
# PSB           Partido Socialista Brasileiro             305000,00198190,8449,881500,00374323,545254,80...
# PSL           Partido Social Liberal                    3000,003000,00210000,00420000,00170000,0067000...
# UP            Unidade Popular                                                3000,002500,006700,003000,00
# PT            Partido dos Trabalhadores                 29000,0013000,0057000,0024000,00280,00280,0010...
# DC            Democracia Cristã                         24592,5155664,001500,00200,0055664,0024592,514...
# PSC           Partido Social Cristão                    2000,001000,001500,001500,001000,00184,20184,6...
# PL            Partido Liberal                           200,00200,00200,00200,00200,00200,00200,00200,...
# NOVO          Partido Novo                              200,00100,00300,00240,00420,00120,00200,00100,...
# PCB           Partido Comunista Brasileiro                                                 1800,004157,40
# CIDADANIA     Cidadania                                 150463,841500,0020,45800,00600,003000,00400,00...
# PV            Partido Verde                             15000,008400,009000,006000,006000,003168,55530...
# AVANTE        AVANTE                                    15000,00500,00750,00750,00500,001,205000,00500...
# PROS          Partido Republicano da Ordem Social       15000,001250,00102212,0088781,00105000,0021991...
# PMN           Partido da Mobilização Nacional           135,00285,004000,00238,09238,09132,50500,00500...
# PTC           Partido Trabalhista Cristão               100000,001500,002000,004931,0019500,0030000,00...
# PC do B       Partido Comunista do Brasil               1000,00500,006000,0039000,00678,3010200,0045,5...
# MDB           Movimento Democrático Brasileiro          1000,00210000,001000,001000,001000,001000,0011...
# PDT           Partido Democrático Trabalhista           100,00200000,00100000,0015000,0015000,00100000...
# PRTB          Partido Renovador Trabalhista Brasileiro  0,50250,001000,001302,004100,005000,0023,7451,...

# %% [markdown]
# # Vamos visualizar os resultados?
# Na aula, nós vimos como usar o matplotlib para gerar gráficos. Agora, vamos descobrir uma nova forma de fazer o mesmo usando um método nativo Pandas. Experimente colocar `.plot(kind='barh')` após a consulta ou dataframe anterior.
#
# Com este comando, podemos produzir um gráfico (plot) do tipo (kind) de barras horizontais (barh).

# %%
top_10 = total_doacoes_decrescente.head(10)
top_10
# Out:
#                                                                                               VR_RECEITA
# SG_PARTIDO    NM_PARTIDO
# DEM           Democratas                               96000,0015000,00323,451250,005500,001250,00152...
# REDE          Rede Sustentabilidade                    855833,33460833,33750057,60511525,00421907,409...
# PSD           Partido Social Democrático               79,004900000,0079,004900000,0032,6515,001000,0...
# PTB           Partido Trabalhista Brasileiro           70000,0095471,8980096,30320385,19158706,393967...
# PATRIOTA      Patriota                                 700,001000,001500,009,802270,951,0039,5514,001...
# PSDB          Partido da Social Democracia Brasileira  6720,00100780,0023572,00125164,0070336,0056204...
# PODE          Podemos                                  500,00500,00500,00500,00500,00500,0030000,0010...
# PP            PROGRESSISTAS                            482400,005002,7437,3010157,086771,39158400,003...
# REPUBLICANOS  REPUBLICANOS                             36,0018,6580000,0036,0080,0086,0029,10625,0062...
# SOLIDARIEDADE Solidariedade                            35000,0060000,00210000,004000,005000,0090000,0...

# %%
top_10.sort_values(by='VR_RECEITA').plot(kind='barh', color={'red'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-71bc02910220> in <cell line: 1>()
# ----> 1 top_10.sort_values(by='VR_RECEITA').plot(kind='barh', color={'red'})
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     448     def generate(self) -> None:
#     449         self._args_adjust()
# --> 450         self._compute_plot_data()
#     451         self._setup_subplots()
#     452         self._make_plot()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     633         # no non-numeric frames or series allowed
#     634         if is_empty:
# --> 635             raise TypeError("no numeric data to plot")
#     636
#     637         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
#Correção. Não fiz esse.

ultimos_10 = total_doacoes_decrescente.tail(10)
ultimos_10
# Out:
#                                                                                             VR_RECEITA
# SG_PARTIDO NM_PARTIDO
# CIDADANIA  Cidadania                                 150463,841500,0020,45800,00600,003000,00400,00...
# PV         Partido Verde                             15000,008400,009000,006000,006000,003168,55530...
# AVANTE     AVANTE                                    15000,00500,00750,00750,00500,001,205000,00500...
# PROS       Partido Republicano da Ordem Social       15000,001250,00102212,0088781,00105000,0021991...
# PMN        Partido da Mobilização Nacional           135,00285,004000,00238,09238,09132,50500,00500...
# PTC        Partido Trabalhista Cristão               100000,001500,002000,004931,0019500,0030000,00...
# PC do B    Partido Comunista do Brasil               1000,00500,006000,0039000,00678,3010200,0045,5...
# MDB        Movimento Democrático Brasileiro          1000,00210000,001000,001000,001000,001000,0011...
# PDT        Partido Democrático Trabalhista           100,00200000,00100000,0015000,0015000,00100000...
# PRTB       Partido Renovador Trabalhista Brasileiro  0,50250,001000,001302,004100,005000,0023,7451,...

# %%
ultimos_10.plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-80657a4c5b20> in <cell line: 1>()
# ----> 1 ultimos_10.plot(kind='barh')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     998                     data.columns = label_name
#     999
# -> 1000         return plot_backend.plot(data, kind=kind, **kwargs)
#    1001
#    1002     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     448     def generate(self) -> None:
#     449         self._args_adjust()
# --> 450         self._compute_plot_data()
#     451         self._setup_subplots()
#     452         self._make_plot()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     633         # no non-numeric frames or series allowed
#     634         if is_empty:
# --> 635             raise TypeError("no numeric data to plot")
#     636
#     637         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %% [markdown]
# ## Qual o valor médio das doações por tipo de doador?
#
# Agora é sua vez! A partir dos comandos anteriores, faça uma nova consulta para descobrir a mediana de acordo com o tipo de doador.

# %%
df_final[['NM_PARTIDO_DOADOR', 'VR_RECEITA']].groupby(by='NM_PARTIDO_DOADOR').median()
# Out:
# <ipython-input-21-8f09d5a6d9e2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_final[['NM_PARTIDO_DOADOR', 'VR_RECEITA']].groupby(by='NM_PARTIDO_DOADOR').median()
# Empty DataFrame
# Columns: []
# Index: [AVANTE, Cidadania, Democracia Cristã, Democratas, Movimento Democrático Brasileiro, PROGRESSISTAS, Partido Comunista Brasileiro, Partido Comunista do Brasil, Partido Democrático Trabalhista, Partido Liberal, Partido Novo, Partido Renovador Trabalhista Brasileiro, Partido Republicano da Ordem Social, Partido Social Cristão, Partido Social Democrático, Partido Social Liberal, Partido Socialismo e Liberdade, Partido Socialista Brasileiro, Partido Trabalhista Brasileiro, Partido Trabalhista Cristão, Partido Verde, Partido da Mulher Brasileira, Partido da Social Democracia Brasileira, Partido dos Trabalhadores, Patriota, Podemos, REPUBLICANOS, Rede Sustentabilidade, Solidariedade, Unidade Popular]

# %% [markdown]
# ## Qual o valor mais alto de doação por tipo de doador?

# %%
df_final[['NM_PARTIDO_DOADOR', 'VR_RECEITA']].groupby(by='NM_PARTIDO_DOADOR').max()
# Out:
#                                          VR_RECEITA
# NM_PARTIDO_DOADOR
# AVANTE                                        78,36
# Cidadania                                   9000,00
# Democracia Cristã                          94634,00
# Democratas                                   986,00
# Movimento Democrático Brasileiro              98,51
# PROGRESSISTAS                                945,00
# Partido Comunista Brasileiro                4157,40
# Partido Comunista do Brasil                 8226,00
# Partido Democrático Trabalhista                9,15
# Partido Liberal                               95,00
# Partido Novo                                 600,00
# Partido Renovador Trabalhista Brasileiro    5000,00
# Partido Republicano da Ordem Social        96000,00
# Partido Social Cristão                        99,30
# Partido Social Democrático                  9502,40
# Partido Social Liberal                        98,23
# Partido Socialismo e Liberdade             95031,26
# Partido Socialista Brasileiro                936,73
# Partido Trabalhista Brasileiro             95471,89
# Partido Trabalhista Cristão                   54,15
# Partido Verde                                 97,00
# Partido da Mulher Brasileira              150000,00
# Partido da Social Democracia Brasileira      960,00
# Partido dos Trabalhadores                   9382,00
# Patriota                                     970,00
# Podemos                                   950000,00
# REPUBLICANOS                              955503,79
# Rede Sustentabilidade                     949975,00
# Solidariedade                             910000,00
# Unidade Popular                             6700,00

# %% [markdown]
# ## Crie uma tabela com valor máximo, mínimo e a mediana, por estado e tipo de doador

# %%
df_final[['TIPO_DOADOR','SG_UF','VR_RECEITA']].groupby(by=['TIPO_DOADOR','SG_UF']).agg({'VR_RECEITA': ['min', 'median', 'max']})
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1790             try:
# -> 1791                 result = self.grouper._cython_operation(
#    1792                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#    1038         ngroups = self.ngroups
# -> 1039         return cy_op.cython_operation(
#    1040             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     707
# --> 708         return self._cython_op_ndim_compat(
#     709             values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     511                 result_mask = result_mask[None, :]
# --> 512             res = self._call_cython_op(
#     513                 values2d,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     570         out_shape = self._get_output_shape(ngroups, values)
# --> 571         func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     572         values = self._get_cython_vals(values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _get_cython_function(cls, kind, how, dtype, is_numeric)
#     185                 # no fused types -> no __signatures__
# --> 186                 raise NotImplementedError(
#     187                     f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->median,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     759         try:
# --> 760             values = values.astype("f8")
#     761         except ValueError as err:
#
# ValueError: could not convert string to float: '12000,00'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-665b787496e6> in <cell line: 1>()
# ----> 1 df_final[['TIPO_DOADOR','SG_UF','VR_RECEITA']].groupby(by=['TIPO_DOADOR','SG_UF']).agg({'VR_RECEITA': ['min', 'median', 'max']})
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     893
#     894         op = GroupByApply(self, func, args, kwargs)
# --> 895         result = op.agg()
#     896         if not is_dict_like(func) and result is not None:
#     897             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     170
#     171         if is_dict_like(arg):
# --> 172             return self.agg_dict_like()
#     173         elif is_list_like(arg):
#     174             # we require a list, but not a 'str'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg_dict_like(self)
#     502         else:
#     503             # key used for column selection and output
# --> 504             results = {
#     505                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506             }
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in <dictcomp>(.0)
#     503             # key used for column selection and output
#     504             results = {
# --> 505                 key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()
#     506             }
#     507
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     279             # but not the class list / tuple itself.
#     280             func = maybe_mangle_lambdas(func)
# --> 281             ret = self._aggregate_multiple_funcs(func)
#     282             if relabeling:
#     283                 # columns is not narrowed by mypy from relabeling flag
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in _aggregate_multiple_funcs(self, arg)
#     334
#     335             key = base.OutputKey(label=name, position=idx)
# --> 336             results[key] = self.aggregate(func)
#     337
#     338         if any(isinstance(x, DataFrame) for x in results.values()):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     273
#     274         if isinstance(func, str):
# --> 275             return getattr(self, func)(*args, **kwargs)
#     276
#     277         elif isinstance(func, abc.Iterable):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in median(self, numeric_only)
#    2210         numeric_only_bool = self._resolve_numeric_only("median", numeric_only, axis=0)
#    2211
# -> 2212         result = self._cython_agg_general(
#    2213             "median",
#    2214             alt=lambda x: Series(x).median(numeric_only=numeric_only_bool),
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, ignore_failures, **kwargs)
#    1808         # TypeError -> we may have an exception in trying to aggregate
#    1809         #  continue and exclude the block
# -> 1810         new_mgr = data.grouped_reduce(array_func, ignore_failures=ignore_failures)
#    1811
#    1812         if not is_ser and len(new_mgr) < orig_len:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/base.py in grouped_reduce(self, func, ignore_failures)
#     197
#     198         arr = self.array
# --> 199         res = func(arr)
#     200         index = default_index(len(res))
#     201
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1802                 # try to python agg
#    1803                 # TODO: shouldn't min_count matter?
# -> 1804                 result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1805
#    1806             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, values, ndim, alt)
#    1743         #  should always be preserved by the implemented aggregations
#    1744         # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1745         res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1746
#    1747         if isinstance(values, Categorical):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#    1079
#    1080         else:
# -> 1081             result = self._aggregate_series_pure_python(obj, func)
#    1082
#    1083         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#    1102
#    1103         for i, group in enumerate(splitter):
# -> 1104             res = func(group)
#    1105             res = libreduction.extract_result(res)
#    1106
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    2212         result = self._cython_agg_general(
#    2213             "median",
# -> 2214             alt=lambda x: Series(x).median(numeric_only=numeric_only_bool),
#    2215             numeric_only=numeric_only,
#    2216         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in median(self, axis, skipna, level, numeric_only, **kwargs)
#   11915             **kwargs,
#   11916         ):
# > 11917             return NDFrame.median(self, axis, skipna, level, numeric_only, **kwargs)
#   11918
#   11919         setattr(cls, "median", median)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in median(self, axis, skipna, level, numeric_only, **kwargs)
#   11411         **kwargs,
#   11412     ) -> Series | float:
# > 11413         return self._stat_function(
#   11414             "median", nanops.nanmedian, axis, skipna, level, numeric_only, **kwargs
#   11415         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11351                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352             )
# > 11353         return self._reduce(
#   11354             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4814                 )
#    4815             with np.errstate(all="ignore"):
# -> 4816                 return op(delegate, skipna=skipna, **kwds)
#    4817
#    4818     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     761         except ValueError as err:
#     762             # e.g. "could not convert string to float: 'a'"
# --> 763             raise TypeError(str(err)) from err
#     764         if mask is not None:
#     765             values[mask] = np.nan
#
# TypeError: could not convert string to float: '12000,00'

# %% [markdown]
# # Entreviste você mesmo

# %% [markdown]
# Escreva abaixo pelo menos outras três perguntas que podem ser feitas à base de dados. Escreva a pergunta como um comentário acima do código com a consulta em Python.
